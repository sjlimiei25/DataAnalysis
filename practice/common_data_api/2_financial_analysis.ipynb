# %% [markdown]
# ### 2_financial_analysis.ipynb

# %% [markdown]
# ## 응답 데이터 정보
# - basDt       : 기준일자
# - crno        : 법인등록번호
# - bizYear     : 사업연도
# - fnclDcd     : 재무제표구분코드
# - fnclDcdNm   : 재무제표구분코드명
# - acitId      : 계정과목
# - acitNm      : 계정과목명
# - thqrAcitAmt : 당분기계정과목금액
# - crtmAcitAmt : 당기계정과목금액
# - lsqtAcitAmt : 전분기계정과목금액
# - pvtrAcitAmt : 전기계정과목금액
# - bpvtrAcitAmt : 전전기계정과목금액
# - curCd       : 통화코드 (KRW)

# %%
# financial_ss.csv 파일을 읽어서 DataFrame 에 저장
import pandas as pd

df = pd.read_csv('financial_ss.csv')
# df.info()
df.head()
# => 첫번째 컬럼 데이터가 인덱스로서 사용되는 값으로 확인

df = pd.read_csv('financial_ss.csv', index_col=0)
df.head()
# => index_col=0 : 첫번재 데이터(위치)를 인덱스로 선택
# Out:
#       basDt           crno  bizYear                     fnclDcd  \
# 0  20151231  1301110006246     2015  FS_ifrs_ConsolidatedMember
# 1  20151231  1301110006246     2015  FS_ifrs_ConsolidatedMember
# 2  20151231  1301110006246     2015  FS_ifrs_ConsolidatedMember
# 3  20151231  1301110006246     2015  FS_ifrs_ConsolidatedMember
# 4  20151231  1301110006246     2015  FS_ifrs_ConsolidatedMember
#
#           fnclDcdNm                   acitId acitNm  thqrAcitAmt  \
# 0  연결재무제표  [member]              ifrs_Assets   자산총계            0
# 1  연결재무제표  [member]       ifrs_CurrentAssets   유동자산            0
# 2  연결재무제표  [member]  ifrs_CurrentLiabilities   유동부채            0
# 3  연결재무제표  [member]              ifrs_Equity   자본총계            0
# 4  연결재무제표  [member]         ifrs_Liabilities   부채총계            0
#
#        crtmAcitAmt  lsqtAcitAmt      pvtrAcitAmt     bpvtrAcitAmt curCd
# 0  242179521000000            0  230422958000000  214075018000000   KRW
# 1  124814725000000            0  115146026000000  110760271000000   KRW
# 2   50502909000000            0   52013913000000   51315409000000   KRW
# 3  179059805000000            0  168088188000000  150016010000000   KRW
# 4   63119716000000            0   62334770000000   64059008000000   KRW

# %%
# 컬럼별 데이터 타입 => dtypes
df.dtypes

# '기준일자' 컬럼(basDt) 타입을 Datetime으로 변경
# pd.to_datetime(대상) => '대상' 숫자 타입인 경우 포맷(형식) 지정
df['basDt'] = pd.to_datetime(df['basDt'], format='%Y%m%d')
df.dtypes
df.head()
# Out:
#        basDt           crno  bizYear                     fnclDcd  \
# 0 2015-12-31  1301110006246     2015  FS_ifrs_ConsolidatedMember
# 1 2015-12-31  1301110006246     2015  FS_ifrs_ConsolidatedMember
# 2 2015-12-31  1301110006246     2015  FS_ifrs_ConsolidatedMember
# 3 2015-12-31  1301110006246     2015  FS_ifrs_ConsolidatedMember
# 4 2015-12-31  1301110006246     2015  FS_ifrs_ConsolidatedMember
#
#           fnclDcdNm                   acitId acitNm  thqrAcitAmt  \
# 0  연결재무제표  [member]              ifrs_Assets   자산총계            0
# 1  연결재무제표  [member]       ifrs_CurrentAssets   유동자산            0
# 2  연결재무제표  [member]  ifrs_CurrentLiabilities   유동부채            0
# 3  연결재무제표  [member]              ifrs_Equity   자본총계            0
# 4  연결재무제표  [member]         ifrs_Liabilities   부채총계            0
#
#        crtmAcitAmt  lsqtAcitAmt      pvtrAcitAmt     bpvtrAcitAmt curCd
# 0  242179521000000            0  230422958000000  214075018000000   KRW
# 1  124814725000000            0  115146026000000  110760271000000   KRW
# 2   50502909000000            0   52013913000000   51315409000000   KRW
# 3  179059805000000            0  168088188000000  150016010000000   KRW
# 4   63119716000000            0   62334770000000   64059008000000   KRW

# %%
# 재무제표구분코드명(fnclDcdNm) 컬럼의 고유값 목록 확인
df['fnclDcdNm'].unique()

# 위 컬럼 데이터 중 연결재무제표 데이터만 선택
# * contains 함수 사용
# df[df['fnclDcdNm'].str.contains('연결재무제표')]

# * [member] 제거하고, 공백 제거하여 '연결재무제표' 선택
df['fnclDcdNm_main'] = df['fnclDcdNm'].str.replace('[member]', '').str.strip()
df = df[df['fnclDcdNm_main'] == '연결재무제표']

# %%
df
# Out:
#          basDt           crno  bizYear                          fnclDcd  \
# 0   2015-12-31  1301110006246     2015       FS_ifrs_ConsolidatedMember
# 1   2015-12-31  1301110006246     2015       FS_ifrs_ConsolidatedMember
# 2   2015-12-31  1301110006246     2015       FS_ifrs_ConsolidatedMember
# 3   2015-12-31  1301110006246     2015       FS_ifrs_ConsolidatedMember
# 4   2015-12-31  1301110006246     2015       FS_ifrs_ConsolidatedMember
# ..         ...            ...      ...                              ...
# 159 2024-12-31  1301110006246     2024  FS_ifrs-full_ConsolidatedMember
# 160 2024-12-31  1301110006246     2024  FS_ifrs-full_ConsolidatedMember
# 161 2024-12-31  1301110006246     2024  FS_ifrs-full_ConsolidatedMember
# 162 2024-12-31  1301110006246     2024  FS_ifrs-full_ConsolidatedMember
# 163 2024-12-31  1301110006246     2024  FS_ifrs-full_ConsolidatedMember
#
#             fnclDcdNm                           acitId acitNm  thqrAcitAmt  \
# 0    연결재무제표  [member]                      ifrs_Assets   자산총계            0
# 1    연결재무제표  [member]               ifrs_CurrentAssets   유동자산            0
# 2    연결재무제표  [member]          ifrs_CurrentLiabilities   유동부채            0
# 3    연결재무제표  [member]                      ifrs_Equity   자본총계            0
# 4    연결재무제표  [member]                 ifrs_Liabilities   부채총계            0
# ..                ...                              ...    ...          ...
# 159   연결재무제표 [member]          ifrs-full_IssuedCapital    자본금            0
# 160   연결재무제표 [member]            ifrs-full_Liabilities   부채총계            0
# 161   연결재무제표 [member]       ifrs-full_NoncurrentAssets  비유동자산            0
# 162   연결재무제표 [member]  ifrs-full_NoncurrentLiabilities  비유동부채            0
# 163   연결재무제표 [member]       ifrs-full_RetainedEarnings  이익잉여금            0
#
#          crtmAcitAmt  lsqtAcitAmt      pvtrAcitAmt     bpvtrAcitAmt curCd  \
# 0    242179521000000            0  230422958000000  214075018000000   KRW
# 1    124814725000000            0  115146026000000  110760271000000   KRW
# 2     50502909000000            0   52013913000000   51315409000000   KRW
# 3    179059805000000            0  168088188000000  150016010000000   KRW
# 4     63119716000000            0   62334770000000   64059008000000   KRW
# ..               ...          ...              ...              ...   ...
# 159     897514000000            0     897514000000     897514000000   KRW
# 160  112339878000000            0   92228115000000   93674903000000   KRW
# 161  287469682000000            0  259969423000000  229953926000000   KRW
# 162   19013579000000            0   16508663000000   15330051000000   KRW
# 163  370513188000000            0  346652238000000  337946407000000   KRW
#
#     fnclDcdNm_main
# 0           연결재무제표
# 1           연결재무제표
# 2           연결재무제표
# 3           연결재무제표
# 4           연결재무제표
# ..             ...
# 159         연결재무제표
# 160         연결재무제표
# 161         연결재무제표
# 162         연결재무제표
# 163         연결재무제표
#
# [86 rows x 14 columns]

# %%
# 기준일자 컬럼 기준으로 오름차순 정렬. 인덱스행 초기화.
df = df.sort_values(by='basDt').reset_index(drop=True)
# Out:
#         basDt           crno  bizYear                          fnclDcd  \
# 0  2015-12-31  1301110006246     2015       FS_ifrs_ConsolidatedMember
# 1  2015-12-31  1301110006246     2015       FS_ifrs_ConsolidatedMember
# 2  2015-12-31  1301110006246     2015       FS_ifrs_ConsolidatedMember
# 3  2015-12-31  1301110006246     2015       FS_ifrs_ConsolidatedMember
# 4  2015-12-31  1301110006246     2015       FS_ifrs_ConsolidatedMember
# ..        ...            ...      ...                              ...
# 81 2024-12-31  1301110006246     2024  FS_ifrs-full_ConsolidatedMember
# 82 2024-12-31  1301110006246     2024  FS_ifrs-full_ConsolidatedMember
# 83 2024-12-31  1301110006246     2024  FS_ifrs-full_ConsolidatedMember
# 84 2024-12-31  1301110006246     2024  FS_ifrs-full_ConsolidatedMember
# 85 2024-12-31  1301110006246     2024  FS_ifrs-full_ConsolidatedMember
#
#            fnclDcdNm                        acitId acitNm  thqrAcitAmt  \
# 0   연결재무제표  [member]                   ifrs_Assets   자산총계            0
# 1   연결재무제표  [member]            ifrs_CurrentAssets   유동자산            0
# 2   연결재무제표  [member]       ifrs_CurrentLiabilities   유동부채            0
# 3   연결재무제표  [member]                   ifrs_Equity   자본총계            0
# 4   연결재무제표  [member]              ifrs_Liabilities   부채총계            0
# ..               ...                           ...    ...          ...
# 81   연결재무제표 [member]  ifrs-full_CurrentLiabilities   유동부채            0
# 82   연결재무제표 [member]       ifrs-full_IssuedCapital    자본금            0
# 83   연결재무제표 [member]         ifrs-full_Liabilities   부채총계            0
# 84   연결재무제표 [member]    ifrs-full_NoncurrentAssets  비유동자산            0
# 85   연결재무제표 [member]    ifrs-full_RetainedEarnings  이익잉여금            0
#
#         crtmAcitAmt  lsqtAcitAmt      pvtrAcitAmt     bpvtrAcitAmt curCd  \
# 0   242179521000000            0  230422958000000  214075018000000   KRW
# 1   124814725000000            0  115146026000000  110760271000000   KRW
# 2    50502909000000            0   52013913000000   51315409000000   KRW
# 3   179059805000000            0  168088188000000  150016010000000   KRW
# 4    63119716000000            0   62334770000000   64059008000000   KRW
# ..              ...          ...              ...              ...   ...
# 81   93326299000000            0   75719452000000   78344852000000   KRW
# 82     897514000000            0     897514000000     897514000000   KRW
# 83  112339878000000            0   92228115000000   93674903000000   KRW
# 84  287469682000000            0  259969423000000  229953926000000   KRW
# 85  370513188000000            0  346652238000000  337946407000000   KRW
#
#    fnclDcdNm_main
# 0          연결재무제표
# 1          연결재무제표
# 2          연결재무제표
# 3          연결재무제표
# 4          연결재무제표
# ..            ...
# 81         연결재무제표
# 82         연결재무제표
# 83         연결재무제표
# 84         연결재무제표
# 85         연결재무제표
#
# [86 rows x 14 columns]

# %%
# 계정과목명(acitNm) 컬럼의 고유값 확인
df['acitNm'].unique()
# Out:
# array(['자산총계', '유동자산', '유동부채', '자본총계', '부채총계', '비유동자산', '비유동부채',
#        '이익잉여금(결손금)', '자본금', '이익잉여금'], dtype=object)

# %%
# 계정과목이 '부채총계', '자본총계'인 데이터의 당기계정과목금액(crtmAcitAmt) 시각화
# '부채총계'
acit_0 = df[ df['acitNm'] == '부채총계' ]
acit_0_amt = acit_0['crtmAcitAmt']

data0 = acit_0_amt.iloc[0]

# '자본총계'
data1 = df[ df['acitNm'] == '자본총계' ]['crtmAcitAmt'].iloc[0]

import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')

plt.figure()
plt.pie([data0, data1], labels=['부채총계', '자본총계'] , autopct='%1.1f%%', colors=['lightcoral', 'skyblue'], explode=(0.05, 0), shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2d6b0209290>,
#   <matplotlib.patches.Wedge at 0x2d6b020b0d0>],
#  [Text(0.785563278116679, 0.8398751907721632, '부채총계'),
#   Text(-0.7514084264010633, -0.8033588094578151, '자본총계')],
#  [Text(0.4440140267616011, 0.4747120643494835, '26.1%'),
#   Text(-0.4098591416733072, -0.4381957142497173, '73.9%')])
